# %%
a=10

# %%
b=44

# %%
c=a+b

# %%
c
# Out:
# 54

# %%
name="Shubham"

# %%
name
# Out:
# 'Shubham'

# %%
print(a+b,name)
# Out:
# 54 Shubham

# %%
print(name,"The roll no is ",c)
# Out:
# Shubham The roll no is  54

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
c=a+b
print(float(c))
# Out:
# 54.0

# %%
type(name)
# Out:
# str

# %%
a=4566
