# %%
name="shubham"

# %%
name.upper()
# Out:
# 'SHUBHAM'

# %%
name.lower()
# Out:
# 'shubham'

# %%
print(len(name))
# Out:
# 7

# %%
name_2="krishna"

# %%
print(name,name_2)
# Out:
# shubham krishna

# %%
str=print(name_2,"Loves",name)
# Out:
# krishna Loves shubham

# %%
str="krishna Loves shubham"
str.replace("shubham","Radha")
# Out:
# 'krishna Loves Radha'
