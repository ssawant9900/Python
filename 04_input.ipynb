# %%
a=int(input("ENTER THE AGE OF THE PERSON "))
# Out:
# ENTER THE AGE OF THE PERSON  35

# %%
b=int(input("ENTER THE AGE OF THE PERSON'S PARENTS"))
# Out:
# ENTER THE AGE OF THE PERSON'S PARENTS 79

# %%
C=print("The total age of both are: " ,a+b,"yrs")
# Out:
# The total age of both are:  114 yrs
