# %%
result=10**4*(5/2+3)+4*45

# %%
print(result)
# Out:
# 55180.0

# %%
result_1=10+2*3

# %%
print(result_1)
# Out:
# 16

# %%
result_2=(10+2)*3

# %%
print(result_2)
# Out:
# 36

# %%
#if same level of precedence occur in the jupyter book , then the it take the from left to right 
#only for modulus ,divison,addtion,subtraction.
## only for exponents it follows the presedence from right to left.

# %%
#for example 
x=2**3**2

# %%
print(x)
# Out:
# 512

# %%
3**2
# Out:
# 9

# %%
2**9
# Out:
# 512
