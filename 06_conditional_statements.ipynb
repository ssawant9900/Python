# %%
#simple condition statements

# %%
a=int(input("enter the number to verify it lies between 1 to 100 : "))
# Out:
# enter the number to verify it lies between 1 to 100 :  233

# %%
if(1<a<100):
    print("the entered number lies between 1 to 100 : ",a)
else:
     print("the entered number does not lies between 1 to 100 : ",a)
# Out:
# the entered number does not lies between 1 to 100 :  112

# %%
if a>100:
    print("The number is greater than 100 & valid for task : ",a)
elif(a>80):
       print("The number is greater than 80  & valid for task: ",a)
elif(a>60):
       print("The number is greater than 100  & valid for task: ",a)
else:
    print("The number is invalid for task : ",a)
# Out:
# The number is greater than 100 & valid for task :  233

# %%
def greet():
    print("hello good morning user :)")

# %%
greet()
# Out:
# hello good morning user :)

# %%
def input_1(a,b):
    a=int(input("enter the value of A :" ))
    b=int(input("enter the value of B :" ))
    sum=a+b
    print("the value of A+B is :",sum)

# %%
input_1(15,35)
# Out:
# enter the value of A : 23
# enter the value of B : 43
# the value of A+B is : 66
