# %%
code=int(input("enter the value of code : " ))
match code :
    case 200 :
        print("respone ok " )
    case 400:
        print("bad response")
    case 500:
        print("Internet server error")
        print("Please verify the code & retry ")
    case 404 :
        print("error not found ")
    case _:
        print("Enter valid code for indentification") # if nothing match this will execute

print("End of the program")#this will execute all time
# Out:
# enter the value of code :  40
# Enter valid code for indentification
# End of the program
