# %%
l=[23,45,21,34,32,565]
l2=[23,44,55,66]
l[4]
# Out:
# 32

# %%
l[4]=53
print(l)
# Out:
# [23, 45, 21, 34, 53, 565]

# %%
l.insert(2,32)
print(l)
# Out:
# [23, 45, 32, 21, 34, 53, 565]

# %%
l.sort()
print(l)
# Out:
# [21, 23, 32, 34, 45, 53, 565]

# %%
l.extend(l2)
print(l)
# Out:
# [21, 23, 32, 34, 45, 53, 565, 23, 44, 55, 66]

# %%
l[9]
print(l)
# Out:
# [21, 23, 32, 34, 45, 53, 565, 23, 44, 55, 66]

# %%
l.sort()
print(l)
# Out:
# [21, 23, 23, 32, 34, 44, 45, 53, 55, 66, 565]
