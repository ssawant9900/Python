# %%
#tuple
e=(12,34,56,65,78,76,12,12,12)

# %%
#index callling
e[2]
# Out:
# 56

# %%
#packing of tuple
profession=("Shubham",20,"Data Scientist","Astrology")
#unpacking of tuple 
name,age,career,hobby=profession

# %%
print(f"My name is {name} & age is {age} current pursuing {career} and have hobby of {hobby}")
# Out:
# My name is Shubham & age is 20 current pursuing Data Scientist and have hobby of Astrology

# %%
print("The number is repeated " ,e.count(12),"Time")
# Out:
# The number is repeated  1 Time

# %%
#slicing
print(e[0:6])
# Out:
# (12, 34, 56, 65, 78, 76)
