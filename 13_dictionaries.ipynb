# %%
Employee= {
    "ID":1123,
    "name":"Shubham",
    "age":19,
    "career":"Data Scientist",
    "Grade" :"A+",
}
Employee_2= {
    "ID":2244,
    "name":"Sharad",
    "age":59,
    "career":"Data Manager",
    "Grade" :"O+",
}

# %%
Employee["Grade"]
# Out:
# 'A+'

# %%
print("""Employee_career_caller 
Please Enter the Employee ID below""")

x=int(input("Enter the employee ID : "))
pass
match x :
    case 2244 :
        print(Employee_2.get("career"))
    case 1123 :
        print(Employee.get("career"))
    case _:
        print("Tbe Employee Id not Found")
# Out:
# Employee_career_caller
# Please Enter the Employee ID below

# %%
print(Employee_career_caller)
# Out:
# Data Scientist

# %%
Employee.keys()
# Out:
# dict_keys(['ID', 'name', 'age', 'career', 'Grade'])
